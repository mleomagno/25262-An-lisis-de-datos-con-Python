# %% [markdown]
# # 📘 Pre-entrega
#
# **Nombre del alumno:** MAGDALENA LEOMAGNO

# %% [markdown]
# ### 1️⃣ Carga de datos

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount ('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# Primero, monta tu Google Drive. Cuando ejecutes la siguiente celda, se te pedirá que autorices a Colab a acceder a tus archivos de Google Drive.

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['ColabNotebooks',
#  'Todo',
#  '.ipynb_checkpoints',
#  'Untitled',
#  'Copia de Template_PreEntrega.ipynb']

# %%
import os
os.listdir('/content/drive/MyDrive/ColabNotebooks')
# Out:
# ['Leomagno Magdalena- Python .ipynb',
#  'datasets-20251015T184912Z-1-001.zip',
#  'users.csv',
#  'hotels.csv',
#  'ventas.sqlite',
#  'Kaggle_users.xlsx',
#  'ventas (1).csv',
#  'marketing.csv',
#  'clientes.csv',
#  'Data Set']

# %%
pd.read_csv('/content/drive/MyDrive/ColabNotebooks/clientes.csv')
#df_clientes=pd.read_csv ('/content/drive/MyDrive/ColabNotebooks/clientes.csv')
# Out:
#      id_cliente               nombre  edad         ciudad  ingresos
# 0             1      Aloysia Screase    44  Mar del Plata  42294.68
# 1             2  Kristina Scaplehorn    25        Posadas  24735.04
# 2             3       Filip Castagne    50    Resistencia  35744.85
# 3             4          Liuka Luard    39   Bahía Blanca  27647.96
# 4             5        Dore Cockshtt    28        Rosario  28245.65
# ..          ...                  ...   ...            ...       ...
# 562         563        Dione Forsyde    29        Posadas  26757.73
# 563         564          Fleming Gow    39       Santa Fe  43674.96
# 564         565      Jewelle Mabbett    33        Córdoba  30522.64
# 565         566          Lauri Munns    23    Resistencia  31259.14
# 566         567          Micah Matis    31     Corrientes  42927.86
#
# [567 rows x 5 columns]

# %%
pd.read_csv('/content/drive/MyDrive/ColabNotebooks/marketing.csv')
#df_marketing=pd.read_csv ('/content/drive/MyDrive/ColabNotebooks/marketing.csv')
# Out:
#     id_campanha            producto  canal  costo fecha_inicio   fecha_fin
# 0            74     Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1            12              Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2            32     Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3            21          Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4            58            Alfombra  Email   4.25   31/03/2024  05/05/2024
# ..          ...                 ...    ...    ...          ...         ...
# 85           70          Aspiradora     TV   3.06   13/12/2024  29/12/2024
# 86           89           Televisor     TV   4.98   13/12/2024    8/2/2025
# 87           68   Rincón de plantas     TV   5.81   17/12/2024   14/2/2025
# 88           33            Secadora  Email   3.80   20/12/2024    7/1/2025
# 89           11  Freidora eléctrica   RRSS   5.27   29/12/2024   21/1/2025
#
# [90 rows x 6 columns]

# %%
pd.read_csv('/content/drive/MyDrive/ColabNotebooks/ventas (1).csv')
#df_ventas=pd.read_csv ('/content/drive/MyDrive/ColabNotebooks/ventas (1).csv')
# Out:
#       id_venta                producto   precio  cantidad fecha_venta  \
# 0          792       Cuadro decorativo   $69.94       5.0  02/01/2024
# 1          811         Lámpara de mesa  $105.10       5.0  02/01/2024
# 2         1156                Secadora   $97.96       3.0  02/01/2024
# 3         1372                Heladera  $114.35       8.0  02/01/2024
# 4         1546                Secadora  $106.21       4.0  02/01/2024
# ...        ...                     ...      ...       ...         ...
# 3030      1837         Horno eléctrico  $104.12       9.0  30/12/2024
# 3031      2276                  Laptop   $85.27       9.0  30/12/2024
# 3032      2696                  Laptop  $107.81       4.0  30/12/2024
# 3033      2913              Smartphone   $99.85       7.0  30/12/2024
# 3034      2930  Consola de videojuegos   $55.47       6.0  30/12/2024
#
#               categoria
# 0            Decoración
# 1            Decoración
# 2     Electrodomésticos
# 3     Electrodomésticos
# ...

# %% [markdown]
# ### 2️⃣ Análisis exploratorio inicial

# %%
print('Análisis exploratorio de df de Clientes:')

print('Primeras filas Clientes:')
print(df_clientes.head (3))

print('\nÚltimas filas:')
print(df_clientes.tail(5))

print('\nDimensiones (filas, columnas):', df_clientes.shape)

print('\nInformación del DataFrame:')
print(df_clientes.info())

print('\nEstadísticas descriptivas:')
print(df_clientes.describe())

print('\nTipos de datos:')
print(df_clientes.dtypes)
# Out:
# Análisis exploratorio de df de Clientes:
# Primeras filas Clientes:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
#
# Últimas filas:
#      id_cliente           nombre  edad       ciudad  ingresos
# 562         563    Dione Forsyde    29      Posadas  26757.73
# 563         564      Fleming Gow    39     Santa Fe  43674.96
# 564         565  Jewelle Mabbett    33      Córdoba  30522.64
# 565         566      Lauri Munns    23  Resistencia  31259.14
# 566         567      Micah Matis    31   Corrientes  42927.86
#
# Dimensiones (filas, columnas): (567, 5)
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ...

# %%
print('Análisis exploratorio de df de Marketing:')

print('Primeras filas Marketing:')
print(df_marketing.head (3))

print('\nÚltimas filas:')
print(df_marketing.tail())

print('\nDimensiones (filas, columnas):', df_marketing.shape)

print('\nInformación del DataFrame:')
print(df_marketing.info())

print('\nEstadísticas descriptivas:')
print(df_marketing.describe())

print('\nTipos de datos:')
print(df_marketing.dtypes)
# Out:
# Análisis exploratorio de df de Marketing:
# Primeras filas Marketing:
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
#
# Últimas filas:
#     id_campanha            producto  canal  costo fecha_inicio   fecha_fin
# 85           70          Aspiradora     TV   3.06   13/12/2024  29/12/2024
# 86           89           Televisor     TV   4.98   13/12/2024    8/2/2025
# 87           68   Rincón de plantas     TV   5.81   17/12/2024   14/2/2025
# 88           33            Secadora  Email   3.80   20/12/2024    7/1/2025
# 89           11  Freidora eléctrica   RRSS   5.27   29/12/2024   21/1/2025
#
# Dimensiones (filas, columnas): (90, 6)
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# ...

# %%
print('Análisis exploratorio de df de Ventas:')

print('Primeras filas Ventas:')
print(df_ventas.head (3))

print('\nÚltimas filas:')
print(df_ventas.tail())

print('\nDimensiones (filas, columnas):', df_ventas.shape)

print('\nInformación del DataFrame:')
print(df_ventas.info())

print('\nEstadísticas descriptivas:')
print(df_ventas.describe())

print('\nTipos de datos:')
print(df_ventas.dtypes)
# Out:
# Análisis exploratorio de df de Ventas:
# Primeras filas Ventas:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
#
# Últimas filas:
#       id_venta                producto   precio  cantidad fecha_venta  \
# 3030      1837         Horno eléctrico  $104.12       9.0  30/12/2024
# 3031      2276                  Laptop   $85.27       9.0  30/12/2024
# 3032      2696                  Laptop  $107.81       4.0  30/12/2024
# 3033      2913              Smartphone   $99.85       7.0  30/12/2024
# 3034      2930  Consola de videojuegos   $55.47       6.0  30/12/2024
#
#               categoria
# 3030  Electrodomésticos
# 3031        Electrónica
# 3032        Electrónica
# ...

# %%
3️⃣ Calidad de los datos

# %%
def eda(df, nombre):
    print(f"=== {nombre} ===")
    print("shape:", df.shape)
    print("columnas:", list(df.columns))
    print("dtypes:")
    print(df.dtypes)
    print("\nNulos por columna:")
    print(df.isna().sum())
    print("\nPrimeras filas:")
    display(df.head(5))
    print("\nDescribe (numérico):")
    display(df.describe(include='number'))
    print("-"*100)

# %%
#Seleccionar columna
print('Columna producto de df_ventas:')
print(df_ventas['producto'].head())

#Varias Columnas
print('\nProducto y precio de df_ventas:')
print(df_ventas[['producto', 'precio']].head())

#Selección con loc
print('\nValor con loc (primer producto):')
print(df_ventas.loc[0, 'producto'])

#Selección con iloc
print('\nValor con iloc (segundo precio):')
print(df_ventas.iloc[1, 2])

#Filtro con query
print('\nVentas con cantidad mayor a 2:')
print(df_ventas.query('cantidad > 2').head())
# Out:
# Columna producto de df_ventas:
# 0    Cuadro decorativo
# 1      Lámpara de mesa
# 2             Secadora
# 3             Heladera
# 4             Secadora
# Name: producto, dtype: object
#
# Producto y precio de df_ventas:
#             producto   precio
# 0  Cuadro decorativo   $69.94
# 1    Lámpara de mesa  $105.10
# 2           Secadora   $97.96
# 3           Heladera  $114.35
# 4           Secadora  $106.21
#
# Valor con loc (primer producto):
# Cuadro decorativo
#
# Valor con iloc (segundo precio):
# $105.10
#
# Ventas con cantidad mayor a 2:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# ...

# %%
### 4️⃣ Limpieza de datos

# %%
#Eliminar nulos
print('DataFrame sin nulos (aplicado a df_ventas):')
print(df_ventas.dropna().head())

#Rellenar nulos
print('\nRelleno de nulos con 0 (aplicado a df_ventas):')
print(df_ventas.fillna(0).head())

#Renombrar columnas
df_ventas_ren = df_ventas.rename(columns={'producto': 'NombreProducto'})
print('\nRenombrado de columna producto (aplicado a df_ventas):')
print(df_ventas_ren.head())

#Eliminar columna
print('\nSin columna precio (aplicado a df_ventas):')
print(df_ventas.drop('precio', axis=1).head())

#Eliminar duplicados
print('\nEliminar duplicados (aplicado a df_ventas):')
print(df_ventas.drop_duplicates().head())
# Out:
# DataFrame sin nulos (aplicado a df_ventas):
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
#
# Relleno de nulos con 0 (aplicado a df_ventas):
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# ...

# %%
### 5️⃣ Transformación de datos

# %%
# Ordenar por Cantidad
print('Ordenado por cantidad (aplicado a df_ventas):')
print(df_ventas.sort_values('cantidad').head())


# Agrupar por Producto
print('\nAgrupado por producto (aplicado a df_ventas):')
print(df_ventas.groupby('producto').head())

#Contar valores de producto
print('\nContar valores de producto (aplicado a df_ventas):')
print(df_ventas['producto'].value_counts().head())

#Apply
print ('\nPrecio con IVA (21%):')
# Assuming 'precio' column needs cleaning (removing '$' and converting to numeric)
df_ventas['precio_numeric'] = df_ventas['precio'].astype(str).str.replace('$', '').astype(float)
print(df_ventas['precio_numeric'].apply(lambda x: x * 1.21).head())

#Map
print ('\nProducto en mayúsculas:')
print(df_ventas['producto'].map(str.upper).head())
# Out:
# Ordenado por cantidad (aplicado a df_ventas):
#       id_venta             producto   precio  cantidad fecha_venta  \
# 56        2501  Parlantes Bluetooth   $87.78       1.0  08/01/2024
# 2991      1907      Horno eléctrico   $47.50       1.0  25/12/2024
# 1862      2563           Smartphone   $90.19       1.0  03/08/2024
# 1622      1072           Microondas   $93.79       1.0  05/07/2024
# 1087       988    Rincón de plantas  $115.47       1.0  30/04/2024
#
#               categoria
# 56          Electrónica
# 2991  Electrodomésticos
# 1862        Electrónica
# 1622  Electrodomésticos
# 1087         Decoración
#
# Agrupado por producto (aplicado a df_ventas):
#      id_venta           producto   precio  cantidad fecha_venta  \
# 0         792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1         811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2        1156           Secadora   $97.96       3.0  02/01/2024
# ...

# %%
### 6️⃣ Agregación

# %%
### 7️⃣ Integración de datos, opcional, NO OBLIGATORIO
